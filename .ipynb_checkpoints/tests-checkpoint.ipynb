# %%
from multi2 import *
import numpy as np

# %%
params = {
    'processors' : [1, 2, 4, 8, 12],
    'nodes' : list(range(100, 401, 100)), 
    'probability' : np.linspace(.1, .3, 5),
    'blocking' : {
        'random' : random, 
        'descending chunks' : descending_degree_chunks,
        'descending within chunks' : descending_degree_within
    }
}

# %%
def run_tests(G, p, blocking):
    final_dict = {}
    
    final_dict['avg_deg'] = avg_degree(G)

    start_time = time.process_time()
    color_p, num_conflicts = parallel_color_strat(G, p, blocking)
    end_time = time.process_time()
    
    final_dict['runtime_parallel'] = end_time - start_time
    final_dict['num_conflicts'] = num_conflicts
    final_dict['chrom_num_parallel'] = max(color_p.values())

    start_time = time.process_time()
    color_g = greedy_color(G)
    end_time = time.process_time()
    
    final_dict['runtime_greedy'] = end_time - start_time
    final_dict['chrom_num_greedy'] = max(color_g.values())

    return final_dict

# %%
# %%time
result_dict = {}
print(len(params['processors']) * len(params['nodes']) * len(params['probability']) * len(params['blocking']))
# nodes, prob, cores, blocking

    
for n in params['nodes']:
    result_dict[n] = {}

    for prob in params['probability']:
        result_dict[n][prob] = {}
        g = nx.gnp_random_graph(n, prob)
        
        for p in params['processors']:
            result_dict[n][prob][p] = {}
            
            for method in params['blocking']:
                result_dict[n][prob][p][method] = run_tests(g, p, params['blocking'][method])
                print(n, prob, p, method)

# %%
result_dict
# Out:
# {100: {0.1: {1: {'random': {'avg_deg': 9.68,
#      'runtime_parallel': 0.30025399999999536,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 6,
#      'runtime_greedy': 0.00046299999999632746,
#      'chrom_num_greedy': 5},
#     'descending chunks': {'avg_deg': 9.68,
#      'runtime_parallel': 0.2790210000000002,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 5,
#      'runtime_greedy': 0.0004550000000165255,
#      'chrom_num_greedy': 5},
#     'descending within chunks': {'avg_deg': 9.68,
#      'runtime_parallel': 0.2817579999999964,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 5,
#      'runtime_greedy': 0.0004590000000064265,
#      'chrom_num_greedy': 5}},
#    2: {'random': {'avg_deg': 9.68,
#      'runtime_parallel': 0.29170899999999733,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 6,
#      'runtime_greedy': 0.0004500000000007276,
#      'chrom_num_greedy': 5},
#     'descending chunks': {'avg_deg': 9.68,
#      'runtime_parallel': 0.2820159999999987,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 6,
#      'runtime_greedy': 0.0005009999999856518,
#      'chrom_num_greedy': 5},
#     'descending within chunks': {'avg_deg': 9.68,
#      'runtime_parallel': 0.27646400000000426,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 5,
#      'runtime_greedy': 0.0004459999999824049,
#      'chrom_num_greedy': 5}},
#    4: {'random': {'avg_deg': 9.68,
#      'runtime_parallel': 0.30624299999999494,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 7,
#      'runtime_greedy': 0.0004619999999988522,
#      'chrom_num_greedy': 5},
#     'descending chunks': {'avg_deg': 9.68,
#      'runtime_parallel': 0.312090999999981,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 6,
#      'runtime_greedy': 0.0004619999999988522,
#      'chrom_num_greedy': 5},
#     'descending within chunks': {'avg_deg': 9.68,
#      'runtime_parallel': 0.3082939999999894,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 5,
#      'runtime_greedy': 0.000457000000011476,
#      'chrom_num_greedy': 5}},
#    8: {'random': {'avg_deg': 9.68,
#      'runtime_parallel': 0.33641099999999824,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 6,
#      'runtime_greedy': 0.00046299999999632746,
#      'chrom_num_greedy': 5},
#     'descending chunks': {'avg_deg': 9.68,
#      'runtime_parallel': 0.3393570000000068,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 5,
#      'runtime_greedy': 0.0004590000000348482,
#      'chrom_num_greedy': 5},
#     'descending within chunks': {'avg_deg': 9.68,
#      'runtime_parallel': 0.3375599999999963,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 5,
#      'runtime_greedy': 0.0005009999999856518,
#      'chrom_num_greedy': 5}},
#    12: {'random': {'avg_deg': 9.68,
#      'runtime_parallel': 0.33007099999997536,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 6,
#      'runtime_greedy': 0.0005160000000046239,
#      'chrom_num_greedy': 5},
#     'descending chunks': {'avg_deg': 9.68,
#      'runtime_parallel': 0.32986499999998387,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 5,
#      'runtime_greedy': 0.0004640000000222244,
#      'chrom_num_greedy': 5},
#     'descending within chunks': {'avg_deg': 9.68,
#      'runtime_parallel': 0.33278300000000627,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 6,
#      'runtime_greedy': 0.0004849999999692045,
#      'chrom_num_greedy': 5}}},
#   0.15: {1: {'random': {'avg_deg': 15.22,
#      'runtime_parallel': 0.2808039999999892,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 8,
#      'runtime_greedy': 0.0005050000000323962,
#      'chrom_num_greedy': 7},
#     'descending chunks': {'avg_deg': 15.22,
#      'runtime_parallel': 0.2734790000000089,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 7,
#      'runtime_greedy': 0.00048099999997930354,
#      'chrom_num_greedy': 7},
#     'descending within chunks': {'avg_deg': 15.22,
#      'runtime_parallel': 0.26169100000004164,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 7,
#      'runtime_greedy': 0.00044400000001587614,
#      'chrom_num_greedy': 7}},
#    2: {'random': {'avg_deg': 15.22,
#      'runtime_parallel': 0.28727399999996805,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 8,
#      'runtime_greedy': 0.0004920000000083746,
#      'chrom_num_greedy': 7},
#     'descending chunks': {'avg_deg': 15.22,
#      'runtime_parallel': 0.2876420000000053,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 7,
#      'runtime_greedy': 0.0005149999999503052,
#      'chrom_num_greedy': 7},
#     'descending within chunks': {'avg_deg': 15.22,
#      'runtime_parallel': 0.295421000000033,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 7,
#      'runtime_greedy': 0.0004890000000159489,
#      'chrom_num_greedy': 7}},
#    4: {'random': {'avg_deg': 15.22,
#      'runtime_parallel': 0.33103700000003755,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 8,
#      'runtime_greedy': 0.0005529999999680513,
#      'chrom_num_greedy': 7},
#     'descending chunks': {'avg_deg': 15.22,
#      'runtime_parallel': 0.3384360000000015,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 7,
#      'runtime_greedy': 0.0005330000000185464,
#      'chrom_num_greedy': 7},
#     'descending within chunks': {'avg_deg': 15.22,
#      'runtime_parallel': 0.3325189999999907,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 7,
#      'runtime_greedy': 0.0005579999999554275,
#      'chrom_num_greedy': 7}},
#    8: {'random': {'avg_deg': 15.22,
#      'runtime_parallel': 0.38975399999998217,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 8,
#      'runtime_greedy': 0.000555999999960477,
#      'chrom_num_greedy': 7},
#     'descending chunks': {'avg_deg': 15.22,
#      'runtime_parallel': 0.43009499999999434,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 7,
#      'runtime_greedy': 0.0005459999999857246,
#      'chrom_num_greedy': 7},
#     'descending within chunks': {'avg_deg': 15.22,
#      'runtime_parallel': 0.4371659999999906,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 8,
#      'runtime_greedy': 0.0009019999999964057,
#      'chrom_num_greedy': 7}},
#    12: {'random': {'avg_deg': 15.22,
#      'runtime_parallel': 0.3766300000000342,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 8,
#      'runtime_greedy': 0.0005090000000222972,
#      'chrom_num_greedy': 7},
#     'descending chunks': {'avg_deg': 15.22,
#      'runtime_parallel': 0.35526699999996936,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 7,
#      'runtime_greedy': 0.0005600000000072214,
#      'chrom_num_greedy': 7},
#     'descending within chunks': {'avg_deg': 15.22,
#      'runtime_parallel': 0.37000000000000455,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0005380000000059226,
#      'chrom_num_greedy': 7}}},
#   0.2: {1: {'random': {'avg_deg': 19.38,
#      'runtime_parallel': 0.28877799999997933,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 10,
#      'runtime_greedy': 0.0004979999999932261,
#      'chrom_num_greedy': 9},
#     'descending chunks': {'avg_deg': 19.38,
#      'runtime_parallel': 0.2738579999999615,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.000542000000052667,
#      'chrom_num_greedy': 9},
#     'descending within chunks': {'avg_deg': 19.38,
#      'runtime_parallel': 0.2763329999999655,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0004959999999982756,
#      'chrom_num_greedy': 9}},
#    2: {'random': {'avg_deg': 19.38,
#      'runtime_parallel': 0.28652800000003253,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0005009999999856518,
#      'chrom_num_greedy': 9},
#     'descending chunks': {'avg_deg': 19.38,
#      'runtime_parallel': 0.28846899999996367,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0005010000000424952,
#      'chrom_num_greedy': 9},
#     'descending within chunks': {'avg_deg': 19.38,
#      'runtime_parallel': 0.2848839999999768,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0005759999999668253,
#      'chrom_num_greedy': 9}},
#    4: {'random': {'avg_deg': 19.38,
#      'runtime_parallel': 0.32002400000004627,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0004749999999944521,
#      'chrom_num_greedy': 9},
#     'descending chunks': {'avg_deg': 19.38,
#      'runtime_parallel': 0.3139829999999506,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0004669999999578067,
#      'chrom_num_greedy': 9},
#     'descending within chunks': {'avg_deg': 19.38,
#      'runtime_parallel': 0.31640899999996464,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.00047200000000202635,
#      'chrom_num_greedy': 9}},
#    8: {'random': {'avg_deg': 19.38,
#      'runtime_parallel': 0.3564180000000192,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 10,
#      'runtime_greedy': 0.0005120000000147229,
#      'chrom_num_greedy': 9},
#     'descending chunks': {'avg_deg': 19.38,
#      'runtime_parallel': 0.35468399999996336,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0005140000000096734,
#      'chrom_num_greedy': 9},
#     'descending within chunks': {'avg_deg': 19.38,
#      'runtime_parallel': 0.34978799999998955,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0005170000000020991,
#      'chrom_num_greedy': 9}},
#    12: {'random': {'avg_deg': 19.38,
#      'runtime_parallel': 0.33808299999998326,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 10,
#      'runtime_greedy': 0.0005479999999806751,
#      'chrom_num_greedy': 9},
#     'descending chunks': {'avg_deg': 19.38,
#      'runtime_parallel': 0.3402849999999944,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0005200000000513683,
#      'chrom_num_greedy': 9},
#     'descending within chunks': {'avg_deg': 19.38,
#      'runtime_parallel': 0.34025700000000825,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0004799999999818283,
#      'chrom_num_greedy': 9}}},
#   0.25: {1: {'random': {'avg_deg': 25.14,
#      'runtime_parallel': 0.27395500000000084,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0005809999999542015,
#      'chrom_num_greedy': 11},
#     'descending chunks': {'avg_deg': 25.14,
#      'runtime_parallel': 0.2750480000000266,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0007130000000188375,
#      'chrom_num_greedy': 11},
#     'descending within chunks': {'avg_deg': 25.14,
#      'runtime_parallel': 0.2749059999999872,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0005090000000222972,
#      'chrom_num_greedy': 11}},
#    2: {'random': {'avg_deg': 25.14,
#      'runtime_parallel': 0.29205100000001494,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0004969999999957508,
#      'chrom_num_greedy': 11},
#     'descending chunks': {'avg_deg': 25.14,
#      'runtime_parallel': 0.3048860000000104,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0006119999999896208,
#      'chrom_num_greedy': 11},
#     'descending within chunks': {'avg_deg': 25.14,
#      'runtime_parallel': 0.3084479999999985,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0007690000000479813,
#      'chrom_num_greedy': 11}},
#    4: {'random': {'avg_deg': 25.14,
#      'runtime_parallel': 0.33443299999999,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0005080000000248219,
#      'chrom_num_greedy': 11},
#     'descending chunks': {'avg_deg': 25.14,
#      'runtime_parallel': 0.33918799999997873,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0005350000000134969,
#      'chrom_num_greedy': 11},
#     'descending within chunks': {'avg_deg': 25.14,
#      'runtime_parallel': 0.3354269999999815,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.000509999999962929,
#      'chrom_num_greedy': 11}},
#    8: {'random': {'avg_deg': 25.14,
#      'runtime_parallel': 0.3926810000000387,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0005800000000135697,
#      'chrom_num_greedy': 11},
#     'descending chunks': {'avg_deg': 25.14,
#      'runtime_parallel': 0.3974649999999542,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0005449999999882493,
#      'chrom_num_greedy': 11},
#     'descending within chunks': {'avg_deg': 25.14,
#      'runtime_parallel': 0.39775400000002037,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0004950000000008004,
#      'chrom_num_greedy': 11}},
#    12: {'random': {'avg_deg': 25.14,
#      'runtime_parallel': 0.3749950000000126,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0006159999999795218,
#      'chrom_num_greedy': 11},
#     'descending chunks': {'avg_deg': 25.14,
#      'runtime_parallel': 0.3672329999999988,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 10,
#      'runtime_greedy': 0.000638000000037664,
#      'chrom_num_greedy': 11},
#     'descending within chunks': {'avg_deg': 25.14,
#      'runtime_parallel': 0.36378500000000713,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.0005049999999755528,
#      'chrom_num_greedy': 11}}},
#   0.3: {1: {'random': {'avg_deg': 28.72,
#      'runtime_parallel': 0.2948889999999551,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.000872000000015305,
#      'chrom_num_greedy': 12},
#     'descending chunks': {'avg_deg': 28.72,
#      'runtime_parallel': 0.31349599999998645,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0007309999999733918,
#      'chrom_num_greedy': 12},
#     'descending within chunks': {'avg_deg': 28.72,
#      'runtime_parallel': 0.2858479999999872,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0005479999999806751,
#      'chrom_num_greedy': 12}},
#    2: {'random': {'avg_deg': 28.72,
#      'runtime_parallel': 0.2900210000000243,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.0005109999999604042,
#      'chrom_num_greedy': 12},
#     'descending chunks': {'avg_deg': 28.72,
#      'runtime_parallel': 0.31026900000000524,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0005830000000059954,
#      'chrom_num_greedy': 12},
#     'descending within chunks': {'avg_deg': 28.72,
#      'runtime_parallel': 0.3085169999999948,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0006079999999997199,
#      'chrom_num_greedy': 12}},
#    4: {'random': {'avg_deg': 28.72,
#      'runtime_parallel': 0.3348050000000171,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0005799999999567262,
#      'chrom_num_greedy': 12},
#     'descending chunks': {'avg_deg': 28.72,
#      'runtime_parallel': 0.3481540000000223,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0005770000000211439,
#      'chrom_num_greedy': 12},
#     'descending within chunks': {'avg_deg': 28.72,
#      'runtime_parallel': 0.34750999999999976,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0005390000000033979,
#      'chrom_num_greedy': 12}},
#    8: {'random': {'avg_deg': 28.72,
#      'runtime_parallel': 0.39769699999999375,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 14,
#      'runtime_greedy': 0.0005419999999958236,
#      'chrom_num_greedy': 12},
#     'descending chunks': {'avg_deg': 28.72,
#      'runtime_parallel': 0.37116900000000896,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0005879999999933716,
#      'chrom_num_greedy': 12},
#     'descending within chunks': {'avg_deg': 28.72,
#      'runtime_parallel': 0.4016730000000166,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.0004959999999982756,
#      'chrom_num_greedy': 12}},
#    12: {'random': {'avg_deg': 28.72,
#      'runtime_parallel': 0.3571380000000204,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.0005499999999756255,
#      'chrom_num_greedy': 12},
#     'descending chunks': {'avg_deg': 28.72,
#      'runtime_parallel': 0.3604440000000295,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.000550000000032469,
#      'chrom_num_greedy': 12},
#     'descending within chunks': {'avg_deg': 28.72,
#      'runtime_parallel': 0.37443599999994603,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.00057499999996935,
#      'chrom_num_greedy': 12}}}},
#  200: {0.1: {1: {'random': {'avg_deg': 19.94,
#      'runtime_parallel': 0.6069769999999721,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0011680000000069413,
#      'chrom_num_greedy': 9},
#     'descending chunks': {'avg_deg': 19.94,
#      'runtime_parallel': 0.5984569999999962,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0010669999999777247,
#      'chrom_num_greedy': 9},
#     'descending within chunks': {'avg_deg': 19.94,
#      'runtime_parallel': 0.608885999999984,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0010220000000344953,
#      'chrom_num_greedy': 9}},
#    2: {'random': {'avg_deg': 19.94,
#      'runtime_parallel': 0.6242460000000278,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 10,
#      'runtime_greedy': 0.0008729999999559368,
#      'chrom_num_greedy': 9},
#     'descending chunks': {'avg_deg': 19.94,
#      'runtime_parallel': 0.6024989999999661,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 10,
#      'runtime_greedy': 0.0010629999999878237,
#      'chrom_num_greedy': 9},
#     'descending within chunks': {'avg_deg': 19.94,
#      'runtime_parallel': 0.6142770000000155,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0009080000000381006,
#      'chrom_num_greedy': 9}},
#    4: {'random': {'avg_deg': 19.94,
#      'runtime_parallel': 0.6377359999999612,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 10,
#      'runtime_greedy': 0.0009380000000192013,
#      'chrom_num_greedy': 9},
#     'descending chunks': {'avg_deg': 19.94,
#      'runtime_parallel': 0.6250049999999874,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 10,
#      'runtime_greedy': 0.0008189999999785869,
#      'chrom_num_greedy': 9},
#     'descending within chunks': {'avg_deg': 19.94,
#      'runtime_parallel': 0.6250679999999988,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0008430000000316795,
#      'chrom_num_greedy': 9}},
#    8: {'random': {'avg_deg': 19.94,
#      'runtime_parallel': 0.689487999999983,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0008540000000039072,
#      'chrom_num_greedy': 9},
#     'descending chunks': {'avg_deg': 19.94,
#      'runtime_parallel': 0.6932499999999777,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0008139999999912106,
#      'chrom_num_greedy': 9},
#     'descending within chunks': {'avg_deg': 19.94,
#      'runtime_parallel': 0.6953749999999559,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0007380000000125619,
#      'chrom_num_greedy': 9}},
#    12: {'random': {'avg_deg': 19.94,
#      'runtime_parallel': 0.7217180000000099,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0008970000000090295,
#      'chrom_num_greedy': 9},
#     'descending chunks': {'avg_deg': 19.94,
#      'runtime_parallel': 0.8111200000000167,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 9,
#      'runtime_greedy': 0.0009749999999826287,
#      'chrom_num_greedy': 9},
#     'descending within chunks': {'avg_deg': 19.94,
#      'runtime_parallel': 0.7724739999999883,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 10,
#      'runtime_greedy': 0.0010450000000332693,
#      'chrom_num_greedy': 9}}},
#   0.15: {1: {'random': {'avg_deg': 29.53,
#      'runtime_parallel': 0.5943109999999479,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.0012140000000044893,
#      'chrom_num_greedy': 11},
#     'descending chunks': {'avg_deg': 29.53,
#      'runtime_parallel': 0.5963899999999853,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0011680000000069413,
#      'chrom_num_greedy': 11},
#     'descending within chunks': {'avg_deg': 29.53,
#      'runtime_parallel': 0.5650489999999877,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.001262999999994463,
#      'chrom_num_greedy': 11}},
#    2: {'random': {'avg_deg': 29.53,
#      'runtime_parallel': 0.6130150000000185,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 14,
#      'runtime_greedy': 0.0008119999999962602,
#      'chrom_num_greedy': 11},
#     'descending chunks': {'avg_deg': 29.53,
#      'runtime_parallel': 0.5888720000000376,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.000918000000012853,
#      'chrom_num_greedy': 11},
#     'descending within chunks': {'avg_deg': 29.53,
#      'runtime_parallel': 0.6094850000000065,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0009890000000041255,
#      'chrom_num_greedy': 11}},
#    4: {'random': {'avg_deg': 29.53,
#      'runtime_parallel': 0.6838490000000093,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.0010149999999953252,
#      'chrom_num_greedy': 11},
#     'descending chunks': {'avg_deg': 29.53,
#      'runtime_parallel': 0.6566450000000259,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 14,
#      'runtime_greedy': 0.0009039999999913562,
#      'chrom_num_greedy': 11},
#     'descending within chunks': {'avg_deg': 29.53,
#      'runtime_parallel': 0.6403789999999958,
#      'num_conflicts': 4,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0007759999999734646,
#      'chrom_num_greedy': 11}},
#    8: {'random': {'avg_deg': 29.53,
#      'runtime_parallel': 0.6957550000000197,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.0008320000000026084,
#      'chrom_num_greedy': 11},
#     'descending chunks': {'avg_deg': 29.53,
#      'runtime_parallel': 0.7119430000000193,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.001056000000005497,
#      'chrom_num_greedy': 11},
#     'descending within chunks': {'avg_deg': 29.53,
#      'runtime_parallel': 0.7132609999999886,
#      'num_conflicts': 4,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0008829999999875326,
#      'chrom_num_greedy': 11}},
#    12: {'random': {'avg_deg': 29.53,
#      'runtime_parallel': 0.7450090000000387,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0008189999999785869,
#      'chrom_num_greedy': 11},
#     'descending chunks': {'avg_deg': 29.53,
#      'runtime_parallel': 0.760451000000046,
#      'num_conflicts': 4,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0007739999999785141,
#      'chrom_num_greedy': 11},
#     'descending within chunks': {'avg_deg': 29.53,
#      'runtime_parallel': 0.7684350000000109,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.0008169999999836364,
#      'chrom_num_greedy': 11}}},
#   0.2: {1: {'random': {'avg_deg': 39.41,
#      'runtime_parallel': 0.5735369999999875,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.001021999999977652,
#      'chrom_num_greedy': 15},
#     'descending chunks': {'avg_deg': 39.41,
#      'runtime_parallel': 0.5453630000000089,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 15,
#      'runtime_greedy': 0.0009620000000154505,
#      'chrom_num_greedy': 15},
#     'descending within chunks': {'avg_deg': 39.41,
#      'runtime_parallel': 0.5528130000000147,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 15,
#      'runtime_greedy': 0.0013400000000274304,
#      'chrom_num_greedy': 15}},
#    2: {'random': {'avg_deg': 39.41,
#      'runtime_parallel': 0.5823120000000017,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.0008900000000267028,
#      'chrom_num_greedy': 15},
#     'descending chunks': {'avg_deg': 39.41,
#      'runtime_parallel': 0.5707109999999602,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 15,
#      'runtime_greedy': 0.0008909999999673346,
#      'chrom_num_greedy': 15},
#     'descending within chunks': {'avg_deg': 39.41,
#      'runtime_parallel': 0.5789760000000115,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 15,
#      'runtime_greedy': 0.0008619999999837091,
#      'chrom_num_greedy': 15}},
#    4: {'random': {'avg_deg': 39.41,
#      'runtime_parallel': 0.6420810000000188,
#      'num_conflicts': 4,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.0009319999999775064,
#      'chrom_num_greedy': 15},
#     'descending chunks': {'avg_deg': 39.41,
#      'runtime_parallel': 0.6515799999999672,
#      'num_conflicts': 4,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.0012409999999931642,
#      'chrom_num_greedy': 15},
#     'descending within chunks': {'avg_deg': 39.41,
#      'runtime_parallel': 0.6311249999999973,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 15,
#      'runtime_greedy': 0.0010899999999764987,
#      'chrom_num_greedy': 15}},
#    8: {'random': {'avg_deg': 39.41,
#      'runtime_parallel': 0.7323489999999993,
#      'num_conflicts': 4,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.0013420000000223808,
#      'chrom_num_greedy': 15},
#     'descending chunks': {'avg_deg': 39.41,
#      'runtime_parallel': 0.7199939999999856,
#      'num_conflicts': 9,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.0009839999999599058,
#      'chrom_num_greedy': 15},
#     'descending within chunks': {'avg_deg': 39.41,
#      'runtime_parallel': 0.7213240000000383,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.0011010000000055697,
#      'chrom_num_greedy': 15}},
#    12: {'random': {'avg_deg': 39.41,
#      'runtime_parallel': 0.7756650000000036,
#      'num_conflicts': 8,
#      'chrom_num_parallel': 15,
#      'runtime_greedy': 0.0014150000000086038,
#      'chrom_num_greedy': 15},
#     'descending chunks': {'avg_deg': 39.41,
#      'runtime_parallel': 0.7797350000000165,
#      'num_conflicts': 14,
#      'chrom_num_parallel': 15,
#      'runtime_greedy': 0.0010320000000092477,
#      'chrom_num_greedy': 15},
#     'descending within chunks': {'avg_deg': 39.41,
#      'runtime_parallel': 0.7672330000000329,
#      'num_conflicts': 6,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.001017999999987751,
#      'chrom_num_greedy': 15}}},
#   0.25: {1: {'random': {'avg_deg': 49.31,
#      'runtime_parallel': 0.5476099999999633,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.0010470000000282198,
#      'chrom_num_greedy': 18},
#     'descending chunks': {'avg_deg': 49.31,
#      'runtime_parallel': 0.5396259999999984,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.001056000000005497,
#      'chrom_num_greedy': 18},
#     'descending within chunks': {'avg_deg': 49.31,
#      'runtime_parallel': 0.5517689999999789,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.0012340000000108375,
#      'chrom_num_greedy': 18}},
#    2: {'random': {'avg_deg': 49.31,
#      'runtime_parallel': 0.570968999999991,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.000964000000010401,
#      'chrom_num_greedy': 18},
#     'descending chunks': {'avg_deg': 49.31,
#      'runtime_parallel': 0.5816169999999943,
#      'num_conflicts': 4,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.0012659999999868887,
#      'chrom_num_greedy': 18},
#     'descending within chunks': {'avg_deg': 49.31,
#      'runtime_parallel': 0.5780909999999722,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.0009709999999927277,
#      'chrom_num_greedy': 18}},
#    4: {'random': {'avg_deg': 49.31,
#      'runtime_parallel': 0.653376000000037,
#      'num_conflicts': 6,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.0013199999999642387,
#      'chrom_num_greedy': 18},
#     'descending chunks': {'avg_deg': 49.31,
#      'runtime_parallel': 0.7020969999999807,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.0010879999999815482,
#      'chrom_num_greedy': 18},
#     'descending within chunks': {'avg_deg': 49.31,
#      'runtime_parallel': 0.6962290000000166,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.0011569999999778702,
#      'chrom_num_greedy': 18}},
#    8: {'random': {'avg_deg': 49.31,
#      'runtime_parallel': 0.7703960000000052,
#      'num_conflicts': 8,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.0010180000000445943,
#      'chrom_num_greedy': 18},
#     'descending chunks': {'avg_deg': 49.31,
#      'runtime_parallel': 0.7781610000000114,
#      'num_conflicts': 6,
#      'chrom_num_parallel': 20,
#      'runtime_greedy': 0.0011430000000132168,
#      'chrom_num_greedy': 18},
#     'descending within chunks': {'avg_deg': 49.31,
#      'runtime_parallel': 0.8048220000000015,
#      'num_conflicts': 10,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.0013569999999845095,
#      'chrom_num_greedy': 18}},
#    12: {'random': {'avg_deg': 49.31,
#      'runtime_parallel': 0.8016809999999737,
#      'num_conflicts': 15,
#      'chrom_num_parallel': 20,
#      'runtime_greedy': 0.0013370000000350046,
#      'chrom_num_greedy': 18},
#     'descending chunks': {'avg_deg': 49.31,
#      'runtime_parallel': 0.8077370000000315,
#      'num_conflicts': 11,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.0011739999999917927,
#      'chrom_num_greedy': 18},
#     'descending within chunks': {'avg_deg': 49.31,
#      'runtime_parallel': 0.8185199999999782,
#      'num_conflicts': 15,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.001343000000019856,
#      'chrom_num_greedy': 18}}},
#   0.3: {1: {'random': {'avg_deg': 59.18,
#      'runtime_parallel': 0.6167679999999791,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.0012260000000310356,
#      'chrom_num_greedy': 20},
#     'descending chunks': {'avg_deg': 59.18,
#      'runtime_parallel': 0.5589899999999943,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 20,
#      'runtime_greedy': 0.0011240000000043437,
#      'chrom_num_greedy': 20},
#     'descending within chunks': {'avg_deg': 59.18,
#      'runtime_parallel': 0.5633000000000266,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 20,
#      'runtime_greedy': 0.0013329999999882602,
#      'chrom_num_greedy': 20}},
#    2: {'random': {'avg_deg': 59.18,
#      'runtime_parallel': 0.5810800000000427,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 21,
#      'runtime_greedy': 0.001056000000005497,
#      'chrom_num_greedy': 20},
#     'descending chunks': {'avg_deg': 59.18,
#      'runtime_parallel': 0.5881520000000364,
#      'num_conflicts': 4,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.001125000000001819,
#      'chrom_num_greedy': 20},
#     'descending within chunks': {'avg_deg': 59.18,
#      'runtime_parallel': 0.5848859999999831,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 21,
#      'runtime_greedy': 0.0010540000000105465,
#      'chrom_num_greedy': 20}},
#    4: {'random': {'avg_deg': 59.18,
#      'runtime_parallel': 0.6590249999999855,
#      'num_conflicts': 15,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.001109999999982847,
#      'chrom_num_greedy': 20},
#     'descending chunks': {'avg_deg': 59.18,
#      'runtime_parallel': 0.6402719999999817,
#      'num_conflicts': 7,
#      'chrom_num_parallel': 21,
#      'runtime_greedy': 0.00119000000000824,
#      'chrom_num_greedy': 20},
#     'descending within chunks': {'avg_deg': 59.18,
#      'runtime_parallel': 0.6471540000000005,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 21,
#      'runtime_greedy': 0.001105999999992946,
#      'chrom_num_greedy': 20}},
#    8: {'random': {'avg_deg': 59.18,
#      'runtime_parallel': 0.7337790000000268,
#      'num_conflicts': 19,
#      'chrom_num_parallel': 23,
#      'runtime_greedy': 0.001155999999980395,
#      'chrom_num_greedy': 20},
#     'descending chunks': {'avg_deg': 59.18,
#      'runtime_parallel': 0.7142929999999978,
#      'num_conflicts': 11,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.0010770000000093205,
#      'chrom_num_greedy': 20},
#     'descending within chunks': {'avg_deg': 59.18,
#      'runtime_parallel': 0.7274820000000091,
#      'num_conflicts': 11,
#      'chrom_num_parallel': 21,
#      'runtime_greedy': 0.0010929999999689244,
#      'chrom_num_greedy': 20}},
#    12: {'random': {'avg_deg': 59.18,
#      'runtime_parallel': 0.776299999999992,
#      'num_conflicts': 18,
#      'chrom_num_parallel': 24,
#      'runtime_greedy': 0.0011650000000145155,
#      'chrom_num_greedy': 20},
#     'descending chunks': {'avg_deg': 59.18,
#      'runtime_parallel': 0.7754050000000348,
#      'num_conflicts': 14,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.0011759999999867432,
#      'chrom_num_greedy': 20},
#     'descending within chunks': {'avg_deg': 59.18,
#      'runtime_parallel': 0.785378000000037,
#      'num_conflicts': 25,
#      'chrom_num_parallel': 23,
#      'runtime_greedy': 0.001213000000007014,
#      'chrom_num_greedy': 20}}}},
#  300: {0.1: {1: {'random': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 0.8214010000000371,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.001311000000043805,
#      'chrom_num_greedy': 12},
#     'descending chunks': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 0.8159099999999739,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0014050000000338514,
#      'chrom_num_greedy': 12},
#     'descending within chunks': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 0.8119879999999853,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0013759999999933825,
#      'chrom_num_greedy': 12}},
#    2: {'random': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 0.8524750000000267,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 14,
#      'runtime_greedy': 0.001144000000010692,
#      'chrom_num_greedy': 12},
#     'descending chunks': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 0.8634170000000267,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.0010959999999613501,
#      'chrom_num_greedy': 12},
#     'descending within chunks': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 0.8624619999999936,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0014170000000035543,
#      'chrom_num_greedy': 12}},
#    4: {'random': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 0.9398010000000454,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.0011370000000283653,
#      'chrom_num_greedy': 12},
#     'descending chunks': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 0.9311999999999898,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.001132999999981621,
#      'chrom_num_greedy': 12},
#     'descending within chunks': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 0.9370059999999967,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 11,
#      'runtime_greedy': 0.0012009999999804677,
#      'chrom_num_greedy': 12}},
#    8: {'random': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 1.125,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.001151999999990494,
#      'chrom_num_greedy': 12},
#     'descending chunks': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 1.1517110000000343,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0011299999999891952,
#      'chrom_num_greedy': 12},
#     'descending within chunks': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 1.1548010000000204,
#      'num_conflicts': 14,
#      'chrom_num_parallel': 14,
#      'runtime_greedy': 0.0012179999999943902,
#      'chrom_num_greedy': 12}},
#    12: {'random': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 1.0754170000000158,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.001140000000020791,
#      'chrom_num_greedy': 12},
#     'descending chunks': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 1.0845950000000357,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 13,
#      'runtime_greedy': 0.001293999999973039,
#      'chrom_num_greedy': 12},
#     'descending within chunks': {'avg_deg': 29.893333333333334,
#      'runtime_parallel': 1.0767190000000255,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 12,
#      'runtime_greedy': 0.0013059999999995853,
#      'chrom_num_greedy': 12}}},
#   0.15: {1: {'random': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 0.8335819999999785,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.001553999999998723,
#      'chrom_num_greedy': 17},
#     'descending chunks': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 0.8237929999999665,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 17,
#      'runtime_greedy': 0.001469999999983429,
#      'chrom_num_greedy': 17},
#     'descending within chunks': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 0.8312270000000126,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 17,
#      'runtime_greedy': 0.001515999999980977,
#      'chrom_num_greedy': 17}},
#    2: {'random': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 0.8793630000000121,
#      'num_conflicts': 4,
#      'chrom_num_parallel': 17,
#      'runtime_greedy': 0.0014340000000174769,
#      'chrom_num_greedy': 17},
#     'descending chunks': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 0.8786420000000135,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.0015670000000227446,
#      'chrom_num_greedy': 17},
#     'descending within chunks': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 0.8587210000000027,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 17,
#      'runtime_greedy': 0.0016439999999988686,
#      'chrom_num_greedy': 17}},
#    4: {'random': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 0.9608240000000023,
#      'num_conflicts': 4,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.0018779999999765096,
#      'chrom_num_greedy': 17},
#     'descending chunks': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 0.9380350000000135,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.0014409999999998035,
#      'chrom_num_greedy': 17},
#     'descending within chunks': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 0.9393640000000119,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.001533000000051743,
#      'chrom_num_greedy': 17}},
#    8: {'random': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 1.1934850000000097,
#      'num_conflicts': 7,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.0018640000000118562,
#      'chrom_num_greedy': 17},
#     'descending chunks': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 1.2221640000000207,
#      'num_conflicts': 22,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.001442999999994754,
#      'chrom_num_greedy': 17},
#     'descending within chunks': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 1.2376859999999965,
#      'num_conflicts': 28,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.0017030000000204382,
#      'chrom_num_greedy': 17}},
#    12: {'random': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 1.1107250000000022,
#      'num_conflicts': 9,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.0014610000000061518,
#      'chrom_num_greedy': 17},
#     'descending chunks': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 1.103365999999994,
#      'num_conflicts': 9,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.0014520000000288746,
#      'chrom_num_greedy': 17},
#     'descending within chunks': {'avg_deg': 44.653333333333336,
#      'runtime_parallel': 1.113932000000034,
#      'num_conflicts': 15,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.0014709999999809042,
#      'chrom_num_greedy': 17}}},
#   0.2: {1: {'random': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 0.8337319999999977,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 21,
#      'runtime_greedy': 0.0021729999999706706,
#      'chrom_num_greedy': 19},
#     'descending chunks': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 0.8321350000000507,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.0021409999999946194,
#      'chrom_num_greedy': 19},
#     'descending within chunks': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 0.800768000000005,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.0017700000000218097,
#      'chrom_num_greedy': 19}},
#    2: {'random': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 0.8525030000000129,
#      'num_conflicts': 6,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.0016249999999899956,
#      'chrom_num_greedy': 19},
#     'descending chunks': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 0.844694000000004,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 21,
#      'runtime_greedy': 0.0016270000000417895,
#      'chrom_num_greedy': 19},
#     'descending within chunks': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 0.8456459999999879,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.0015609999999810498,
#      'chrom_num_greedy': 19}},
#    4: {'random': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 0.9380709999999794,
#      'num_conflicts': 4,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.001688000000001466,
#      'chrom_num_greedy': 19},
#     'descending chunks': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 0.9378710000000297,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 20,
#      'runtime_greedy': 0.0017950000000155342,
#      'chrom_num_greedy': 19},
#     'descending within chunks': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 0.9393160000000194,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 20,
#      'runtime_greedy': 0.0016899999999964166,
#      'chrom_num_greedy': 19}},
#    8: {'random': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 1.238429999999994,
#      'num_conflicts': 22,
#      'chrom_num_parallel': 23,
#      'runtime_greedy': 0.0018180000000143082,
#      'chrom_num_greedy': 19},
#     'descending chunks': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 1.2817650000000071,
#      'num_conflicts': 43,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.001729000000011638,
#      'chrom_num_greedy': 19},
#     'descending within chunks': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 1.3005810000000224,
#      'num_conflicts': 49,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.001706000000012864,
#      'chrom_num_greedy': 19}},
#    12: {'random': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 1.1321609999999964,
#      'num_conflicts': 21,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.001714999999990141,
#      'chrom_num_greedy': 19},
#     'descending chunks': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 1.123049999999978,
#      'num_conflicts': 16,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.0018710000000510263,
#      'chrom_num_greedy': 19},
#     'descending within chunks': {'avg_deg': 58.906666666666666,
#      'runtime_parallel': 1.1219970000000217,
#      'num_conflicts': 12,
#      'chrom_num_parallel': 20,
#      'runtime_greedy': 0.0018919999999980064,
#      'chrom_num_greedy': 19}}},
#   0.25: {1: {'random': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 0.8192540000000008,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 26,
#      'runtime_greedy': 0.0019080000000144537,
#      'chrom_num_greedy': 25},
#     'descending chunks': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 0.811273999999969,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 25,
#      'runtime_greedy': 0.001978000000008251,
#      'chrom_num_greedy': 25},
#     'descending within chunks': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 0.8227280000000405,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 25,
#      'runtime_greedy': 0.001951000000019576,
#      'chrom_num_greedy': 25}},
#    2: {'random': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 0.8566620000000285,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 25,
#      'runtime_greedy': 0.0019239999999740576,
#      'chrom_num_greedy': 25},
#     'descending chunks': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 0.8569560000000251,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 25,
#      'runtime_greedy': 0.001890000000003056,
#      'chrom_num_greedy': 25},
#     'descending within chunks': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 0.9234460000000126,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 24,
#      'runtime_greedy': 0.00231899999999996,
#      'chrom_num_greedy': 25}},
#    4: {'random': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 1.0767779999999902,
#      'num_conflicts': 14,
#      'chrom_num_parallel': 26,
#      'runtime_greedy': 0.0022810000000390573,
#      'chrom_num_greedy': 25},
#     'descending chunks': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 1.0350760000000037,
#      'num_conflicts': 8,
#      'chrom_num_parallel': 25,
#      'runtime_greedy': 0.001882000000023254,
#      'chrom_num_greedy': 25},
#     'descending within chunks': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 1.0019550000000095,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 24,
#      'runtime_greedy': 0.0025150000000166983,
#      'chrom_num_greedy': 25}},
#    8: {'random': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 1.467198000000053,
#      'num_conflicts': 63,
#      'chrom_num_parallel': 29,
#      'runtime_greedy': 0.002113000000008469,
#      'chrom_num_greedy': 25},
#     'descending chunks': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 1.401551999999981,
#      'num_conflicts': 54,
#      'chrom_num_parallel': 26,
#      'runtime_greedy': 0.0021919999999795436,
#      'chrom_num_greedy': 25},
#     'descending within chunks': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 1.3863210000000095,
#      'num_conflicts': 66,
#      'chrom_num_parallel': 29,
#      'runtime_greedy': 0.002358999999955813,
#      'chrom_num_greedy': 25}},
#    12: {'random': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 1.2698800000000006,
#      'num_conflicts': 40,
#      'chrom_num_parallel': 28,
#      'runtime_greedy': 0.002036999999972977,
#      'chrom_num_greedy': 25},
#     'descending chunks': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 1.205116999999973,
#      'num_conflicts': 25,
#      'chrom_num_parallel': 27,
#      'runtime_greedy': 0.0021229999999832216,
#      'chrom_num_greedy': 25},
#     'descending within chunks': {'avg_deg': 74.74666666666667,
#      'runtime_parallel': 1.2348399999999629,
#      'num_conflicts': 34,
#      'chrom_num_parallel': 28,
#      'runtime_greedy': 0.0027460000000019136,
#      'chrom_num_greedy': 25}}},
#   0.3: {1: {'random': {'avg_deg': 89.11333333333333,
#      'runtime_parallel': 0.8986650000000509,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 28,
#      'runtime_greedy': 0.002223000000014963,
#      'chrom_num_greedy': 27},
#     'descending chunks': {'avg_deg': 89.11333333333333,
#      'runtime_parallel': 0.8787149999999997,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 27,
#      'runtime_greedy': 0.0022329999999897154,
#      'chrom_num_greedy': 27},
#     'descending within chunks': {'avg_deg': 89.11333333333333,
#      'runtime_parallel': 0.837455000000034,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 27,
#      'runtime_greedy': 0.002242000000023836,
#      'chrom_num_greedy': 27}},
#    2: {'random': {'avg_deg': 89.11333333333333,
#      'runtime_parallel': 0.8988100000000259,
#      'num_conflicts': 5,
# ...
#      'chrom_num_greedy': 14}},
#    12: {'random': {'avg_deg': 39.995,
#      'runtime_parallel': 1.516727000000003,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.001763000000039483,
#      'chrom_num_greedy': 14},
#     'descending chunks': {'avg_deg': 39.995,
#      'runtime_parallel': 1.5465209999999843,
#      'num_conflicts': 10,
#      'chrom_num_parallel': 16,
#      'runtime_greedy': 0.0018760000000384025,
#      'chrom_num_greedy': 14},
#     'descending within chunks': {'avg_deg': 39.995,
#      'runtime_parallel': 1.546007999999972,
#      'num_conflicts': 18,
#      'chrom_num_parallel': 17,
#      'runtime_greedy': 0.0018620000000169057,
#      'chrom_num_greedy': 14}}},
#   0.15: {1: {'random': {'avg_deg': 59.23,
#      'runtime_parallel': 1.0712280000000192,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 21,
#      'runtime_greedy': 0.0022220000000174878,
#      'chrom_num_greedy': 19},
#     'descending chunks': {'avg_deg': 59.23,
#      'runtime_parallel': 1.071803999999986,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.002584999999953652,
#      'chrom_num_greedy': 19},
#     'descending within chunks': {'avg_deg': 59.23,
#      'runtime_parallel': 1.066648999999984,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.0024289999999496104,
#      'chrom_num_greedy': 19}},
#    2: {'random': {'avg_deg': 59.23,
#      'runtime_parallel': 1.130108000000007,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 21,
#      'runtime_greedy': 0.0021820000000047912,
#      'chrom_num_greedy': 19},
#     'descending chunks': {'avg_deg': 59.23,
#      'runtime_parallel': 1.1134440000000154,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 20,
#      'runtime_greedy': 0.002330000000029031,
#      'chrom_num_greedy': 19},
#     'descending within chunks': {'avg_deg': 59.23,
#      'runtime_parallel': 1.1247650000000249,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.002214000000037686,
#      'chrom_num_greedy': 19}},
#    4: {'random': {'avg_deg': 59.23,
#      'runtime_parallel': 1.218968000000018,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 21,
#      'runtime_greedy': 0.002262999999970816,
#      'chrom_num_greedy': 19},
#     'descending chunks': {'avg_deg': 59.23,
#      'runtime_parallel': 1.2293700000000172,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 20,
#      'runtime_greedy': 0.0022700000000099863,
#      'chrom_num_greedy': 19},
#     'descending within chunks': {'avg_deg': 59.23,
#      'runtime_parallel': 1.2280590000000302,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.0023789999999621614,
#      'chrom_num_greedy': 19}},
#    8: {'random': {'avg_deg': 59.23,
#      'runtime_parallel': 1.37717200000003,
#      'num_conflicts': 12,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.0021820000000047912,
#      'chrom_num_greedy': 19},
#     'descending chunks': {'avg_deg': 59.23,
#      'runtime_parallel': 1.3786210000000096,
#      'num_conflicts': 13,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.0025479999999902248,
#      'chrom_num_greedy': 19},
#     'descending within chunks': {'avg_deg': 59.23,
#      'runtime_parallel': 1.3943629999999985,
#      'num_conflicts': 7,
#      'chrom_num_parallel': 20,
#      'runtime_greedy': 0.0024890000000254986,
#      'chrom_num_greedy': 19}},
#    12: {'random': {'avg_deg': 59.23,
#      'runtime_parallel': 1.654703999999981,
#      'num_conflicts': 34,
#      'chrom_num_parallel': 23,
#      'runtime_greedy': 0.0022910000000138098,
#      'chrom_num_greedy': 19},
#     'descending chunks': {'avg_deg': 59.23,
#      'runtime_parallel': 1.6519700000000057,
#      'num_conflicts': 36,
#      'chrom_num_parallel': 22,
#      'runtime_greedy': 0.0027539999999817155,
#      'chrom_num_greedy': 19},
#     'descending within chunks': {'avg_deg': 59.23,
#      'runtime_parallel': 1.5999699999999848,
#      'num_conflicts': 26,
#      'chrom_num_parallel': 23,
#      'runtime_greedy': 0.0024589999999875545,
#      'chrom_num_greedy': 19}}},
#   0.2: {1: {'random': {'avg_deg': 80.51,
#      'runtime_parallel': 1.095749000000012,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 27,
#      'runtime_greedy': 0.002904000000000906,
#      'chrom_num_greedy': 24},
#     'descending chunks': {'avg_deg': 80.51,
#      'runtime_parallel': 1.09680800000001,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 24,
#      'runtime_greedy': 0.0031029999999532265,
#      'chrom_num_greedy': 24},
#     'descending within chunks': {'avg_deg': 80.51,
#      'runtime_parallel': 1.1226609999999937,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 24,
#      'runtime_greedy': 0.004190000000050986,
#      'chrom_num_greedy': 24}},
#    2: {'random': {'avg_deg': 80.51,
#      'runtime_parallel': 1.25685500000003,
#      'num_conflicts': 8,
#      'chrom_num_parallel': 27,
#      'runtime_greedy': 0.0026770000000055916,
#      'chrom_num_greedy': 24},
#     'descending chunks': {'avg_deg': 80.51,
#      'runtime_parallel': 1.1337929999999687,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 26,
#      'runtime_greedy': 0.0026960000000144646,
#      'chrom_num_greedy': 24},
#     'descending within chunks': {'avg_deg': 80.51,
#      'runtime_parallel': 1.11484200000001,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 24,
#      'runtime_greedy': 0.00272499999999809,
#      'chrom_num_greedy': 24}},
#    4: {'random': {'avg_deg': 80.51,
#      'runtime_parallel': 1.2461910000000103,
#      'num_conflicts': 11,
#      'chrom_num_parallel': 26,
#      'runtime_greedy': 0.002782000000024709,
#      'chrom_num_greedy': 24},
#     'descending chunks': {'avg_deg': 80.51,
#      'runtime_parallel': 1.2413199999999733,
#      'num_conflicts': 7,
#      'chrom_num_parallel': 25,
#      'runtime_greedy': 0.003964999999993779,
#      'chrom_num_greedy': 24},
#     'descending within chunks': {'avg_deg': 80.51,
#      'runtime_parallel': 1.2705349999999953,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 25,
#      'runtime_greedy': 0.003152999999997519,
#      'chrom_num_greedy': 24}},
#    8: {'random': {'avg_deg': 80.51,
#      'runtime_parallel': 1.4852319999999963,
#      'num_conflicts': 16,
#      'chrom_num_parallel': 26,
#      'runtime_greedy': 0.0033150000000432556,
#      'chrom_num_greedy': 24},
#     'descending chunks': {'avg_deg': 80.51,
#      'runtime_parallel': 1.4445670000000064,
#      'num_conflicts': 27,
#      'chrom_num_parallel': 28,
#      'runtime_greedy': 0.0029360000000338005,
#      'chrom_num_greedy': 24},
#     'descending within chunks': {'avg_deg': 80.51,
#      'runtime_parallel': 1.4218989999999962,
#      'num_conflicts': 14,
#      'chrom_num_parallel': 26,
#      'runtime_greedy': 0.003173000000003867,
#      'chrom_num_greedy': 24}},
#    12: {'random': {'avg_deg': 80.51,
#      'runtime_parallel': 1.7512729999999692,
#      'num_conflicts': 62,
#      'chrom_num_parallel': 30,
#      'runtime_greedy': 0.0031859999999710453,
#      'chrom_num_greedy': 24},
#     'descending chunks': {'avg_deg': 80.51,
#      'runtime_parallel': 1.7264390000000276,
#      'num_conflicts': 49,
#      'chrom_num_parallel': 28,
#      'runtime_greedy': 0.0031629999999722713,
#      'chrom_num_greedy': 24},
#     'descending within chunks': {'avg_deg': 80.51,
#      'runtime_parallel': 1.7409379999999715,
#      'num_conflicts': 57,
#      'chrom_num_parallel': 29,
#      'runtime_greedy': 0.0031209999999646243,
#      'chrom_num_greedy': 24}}},
#   0.25: {1: {'random': {'avg_deg': 99.47,
#      'runtime_parallel': 1.19390199999998,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 32,
#      'runtime_greedy': 0.0040300000000002,
#      'chrom_num_greedy': 30},
#     'descending chunks': {'avg_deg': 99.47,
#      'runtime_parallel': 1.2021200000000363,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 30,
#      'runtime_greedy': 0.003275999999971191,
#      'chrom_num_greedy': 30},
#     'descending within chunks': {'avg_deg': 99.47,
#      'runtime_parallel': 1.153616999999997,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 30,
#      'runtime_greedy': 0.0031819999999811444,
#      'chrom_num_greedy': 30}},
#    2: {'random': {'avg_deg': 99.47,
#      'runtime_parallel': 1.1860060000000203,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 31,
#      'runtime_greedy': 0.003272999999978765,
#      'chrom_num_greedy': 30},
#     'descending chunks': {'avg_deg': 99.47,
#      'runtime_parallel': 1.1654600000000528,
#      'num_conflicts': 1,
#      'chrom_num_parallel': 30,
#      'runtime_greedy': 0.003165999999964697,
#      'chrom_num_greedy': 30},
#     'descending within chunks': {'avg_deg': 99.47,
#      'runtime_parallel': 1.2586959999999863,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 30,
#      'runtime_greedy': 0.0036790000000337386,
#      'chrom_num_greedy': 30}},
#    4: {'random': {'avg_deg': 99.47,
#      'runtime_parallel': 1.4079590000000053,
#      'num_conflicts': 17,
#      'chrom_num_parallel': 33,
#      'runtime_greedy': 0.003237999999953445,
#      'chrom_num_greedy': 30},
#     'descending chunks': {'avg_deg': 99.47,
#      'runtime_parallel': 1.286657000000048,
#      'num_conflicts': 10,
#      'chrom_num_parallel': 32,
#      'runtime_greedy': 0.003451999999981581,
#      'chrom_num_greedy': 30},
#     'descending within chunks': {'avg_deg': 99.47,
#      'runtime_parallel': 1.2948339999999803,
#      'num_conflicts': 10,
#      'chrom_num_parallel': 31,
#      'runtime_greedy': 0.00383300000004283,
#      'chrom_num_greedy': 30}},
#    8: {'random': {'avg_deg': 99.47,
#      'runtime_parallel': 1.5212639999999737,
#      'num_conflicts': 32,
#      'chrom_num_parallel': 34,
#      'runtime_greedy': 0.003773000000023785,
#      'chrom_num_greedy': 30},
#     'descending chunks': {'avg_deg': 99.47,
#      'runtime_parallel': 1.4509070000000293,
#      'num_conflicts': 28,
#      'chrom_num_parallel': 33,
#      'runtime_greedy': 0.003520000000037271,
#      'chrom_num_greedy': 30},
#     'descending within chunks': {'avg_deg': 99.47,
#      'runtime_parallel': 1.4961920000000077,
#      'num_conflicts': 24,
#      'chrom_num_parallel': 32,
#      'runtime_greedy': 0.00359600000001592,
#      'chrom_num_greedy': 30}},
#    12: {'random': {'avg_deg': 99.47,
#      'runtime_parallel': 1.928104000000019,
#      'num_conflicts': 79,
#      'chrom_num_parallel': 37,
#      'runtime_greedy': 0.003880999999978485,
#      'chrom_num_greedy': 30},
#     'descending chunks': {'avg_deg': 99.47,
#      'runtime_parallel': 1.8439149999999813,
#      'num_conflicts': 79,
#      'chrom_num_parallel': 34,
#      'runtime_greedy': 0.003669999999999618,
#      'chrom_num_greedy': 30},
#     'descending within chunks': {'avg_deg': 99.47,
#      'runtime_parallel': 1.8832550000000197,
#      'num_conflicts': 90,
#      'chrom_num_parallel': 36,
#      'runtime_greedy': 0.0034330000000295513,
#      'chrom_num_greedy': 30}}},
#   0.3: {1: {'random': {'avg_deg': 119.22,
#      'runtime_parallel': 1.1731090000000108,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 37,
#      'runtime_greedy': 0.0040399999999749525,
#      'chrom_num_greedy': 34},
#     'descending chunks': {'avg_deg': 119.22,
#      'runtime_parallel': 1.2290020000000368,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 34,
#      'runtime_greedy': 0.004070000000012897,
#      'chrom_num_greedy': 34},
#     'descending within chunks': {'avg_deg': 119.22,
#      'runtime_parallel': 1.1846709999999803,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 34,
#      'runtime_greedy': 0.005012000000021999,
#      'chrom_num_greedy': 34}},
#    2: {'random': {'avg_deg': 119.22,
#      'runtime_parallel': 1.3608029999999758,
#      'num_conflicts': 10,
#      'chrom_num_parallel': 37,
#      'runtime_greedy': 0.004710000000045511,
#      'chrom_num_greedy': 34},
#     'descending chunks': {'avg_deg': 119.22,
#      'runtime_parallel': 1.232512999999983,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 35,
#      'runtime_greedy': 0.004280999999991764,
#      'chrom_num_greedy': 34},
#     'descending within chunks': {'avg_deg': 119.22,
#      'runtime_parallel': 1.3203809999999976,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 35,
#      'runtime_greedy': 0.004120000000000346,
#      'chrom_num_greedy': 34}},
#    4: {'random': {'avg_deg': 119.22,
#      'runtime_parallel': 1.4483099999999922,
#      'num_conflicts': 28,
#      'chrom_num_parallel': 39,
#      'runtime_greedy': 0.004722000000015214,
#      'chrom_num_greedy': 34},
#     'descending chunks': {'avg_deg': 119.22,
#      'runtime_parallel': 1.4556119999999737,
#      'num_conflicts': 11,
#      'chrom_num_parallel': 37,
#      'runtime_greedy': 0.004692999999974745,
#      'chrom_num_greedy': 34},
#     'descending within chunks': {'avg_deg': 119.22,
#      'runtime_parallel': 1.3657740000000445,
#      'num_conflicts': 15,
#      'chrom_num_parallel': 36,
#      'runtime_greedy': 0.004920000000026903,
#      'chrom_num_greedy': 34}},
#    8: {'random': {'avg_deg': 119.22,
#      'runtime_parallel': 1.6191029999999955,
#      'num_conflicts': 51,
#      'chrom_num_parallel': 40,
#      'runtime_greedy': 0.004064999999968677,
#      'chrom_num_greedy': 34},
#     'descending chunks': {'avg_deg': 119.22,
#      'runtime_parallel': 1.6359339999999634,
#      'num_conflicts': 34,
#      'chrom_num_parallel': 38,
#      'runtime_greedy': 0.004065999999966152,
#      'chrom_num_greedy': 34},
#     'descending within chunks': {'avg_deg': 119.22,
#      'runtime_parallel': 1.6918140000000221,
#      'num_conflicts': 37,
#      'chrom_num_parallel': 38,
#      'runtime_greedy': 0.004345000000000709,
#      'chrom_num_greedy': 34}},
#    12: {'random': {'avg_deg': 119.22,
#      'runtime_parallel': 2.268168000000003,
#      'num_conflicts': 143,
#      'chrom_num_parallel': 45,
#      'runtime_greedy': 0.0039000000000442014,
#      'chrom_num_greedy': 34},
#     'descending chunks': {'avg_deg': 119.22,
#      'runtime_parallel': 2.202022999999997,
#      'num_conflicts': 127,
#      'chrom_num_parallel': 43,
#      'runtime_greedy': 0.0040359999999850515,
#      'chrom_num_greedy': 34},
#     'descending within chunks': {'avg_deg': 119.22,
#      'runtime_parallel': 2.3951959999999985,
#      'num_conflicts': 149,
#      'chrom_num_parallel': 43,
#      'runtime_greedy': 0.00448999999997568,
#      'chrom_num_greedy': 34}}}},
#  500: {0.1: {1: {'random': {'avg_deg': 48.924,
#      'runtime_parallel': 1.514047000000005,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.0031819999999811444,
#      'chrom_num_greedy': 17},
#     'descending chunks': {'avg_deg': 48.924,
#      'runtime_parallel': 1.4390889999999672,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 17,
#      'runtime_greedy': 0.002682000000049811,
#      'chrom_num_greedy': 17},
#     'descending within chunks': {'avg_deg': 48.924,
#      'runtime_parallel': 1.5283319999999776,
#      'num_conflicts': 0,
#      'chrom_num_parallel': 17,
#      'runtime_greedy': 0.0027529999999842403,
#      'chrom_num_greedy': 17}},
#    2: {'random': {'avg_deg': 48.924,
#      'runtime_parallel': 1.5159780000000183,
#      'num_conflicts': 7,
#      'chrom_num_parallel': 18,
#      'runtime_greedy': 0.0024690000000191503,
#      'chrom_num_greedy': 17},
#     'descending chunks': {'avg_deg': 48.924,
#      'runtime_parallel': 1.5424909999999272,
#      'num_conflicts': 5,
#      'chrom_num_parallel': 17,
#      'runtime_greedy': 0.002772999999933745,
#      'chrom_num_greedy': 17},
#     'descending within chunks': {'avg_deg': 48.924,
#      'runtime_parallel': 1.436456000000021,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 17,
#      'runtime_greedy': 0.002923000000009779,
#      'chrom_num_greedy': 17}},
#    4: {'random': {'avg_deg': 48.924,
#      'runtime_parallel': 1.6185080000000198,
#      'num_conflicts': 7,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.002652000000011867,
#      'chrom_num_greedy': 17},
#     'descending chunks': {'avg_deg': 48.924,
#      'runtime_parallel': 1.6082999999999856,
#      'num_conflicts': 3,
#      'chrom_num_parallel': 19,
#      'runtime_greedy': 0.0026880000000346627,
#      'chrom_num_greedy': 17},
#     'descending within chunks': {'avg_deg': 48.924,
#      'runtime_parallel': 1.6517100000000937,
#      'num_conflicts': 2,
#      'chrom_num_parallel': 17,
#      'runtime_greedy': 0.002878000000009706,
#      'chrom_num_greedy': 17}},
#    8: {}}}}

# %%
import json

with open('data.txt', 'w') as outfile:
    json.dump(result_dict, outfile)
