# %%
from networkx.generators.random_graphs import gnp_random_graph as graph_gen

from multi2 import *

# %%
# Generate a graph to color
g = graph_gen(20, .3)

# Core number
cores = 4

# %%
# 3 methods described in report
methods = {
        'random' : random, 
        'descending chunks' : descending_degree_chunks,
        'descending within chunks' : descending_degree_within
}

# %%
### Warning: Rerunning cells may have adverse effects due to how Jupyter, Python, and parallel 
### processing interact. It is reccomended to restart the kernel to experiment with different graphs

# %%
# %%time
# Uses core number to determine processes to use
# Ran the same graph with various methods
coloring1, conflicts1 = parallel_color_strat(g, cores, methods['random'])
# Out:
# CPU times: user 30.5 ms, sys: 47 ms, total: 77.5 ms
# Wall time: 119 ms

# %%
# %%time
coloring2, conflicts2 = parallel_color_strat(g, cores, methods['descending chunks'])
# Out:
# CPU times: user 25.9 ms, sys: 45.5 ms, total: 71.4 ms
# Wall time: 122 ms

# %%
# %%time
coloring3, conflicts3 = parallel_color_strat(g, cores, methods['descending within chunks'])
# Out:
# CPU times: user 25.7 ms, sys: 46 ms, total: 71.7 ms
# Wall time: 128 ms

# %%
## This function was taken from 
#https://github.com/MUSoC/Visualization-of-popular-algorithms-in-Python/tree/master/Graph%20Coloring
def DrawGraph(G, col_val):
    pos = nx.spring_layout(G)
    values = [col_val.get(node, 'blue') for node in G.nodes()]
    nx.draw(G, pos, with_labels = True, node_color = values, edge_color = 'black' ,width = 1, alpha = 0.7)  
    #with_labels=true is to show the node number in the output graph

# %%
print('Conflicts:', conflicts1)
DrawGraph(g, coloring1)
# Out:
# Conflicts: 0

# %%
print('Conflicts:', conflicts2)
DrawGraph(g, coloring2)
# Out:
# Conflicts: 0

# %%
print('Conflicts:', conflicts2)
DrawGraph(g, coloring2)
# Out:
# Conflicts: 0
